# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data.csv')
pd.set_option('display.max_columns', 90)
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data.isnull().sum().head()
# Out:
# Unnamed: 0    0
# ID            0
# Name          0
# Age           0
# Photo         0
# dtype: int64

# %%
dropcols = data.columns[28:54]
data_ff = data.drop(dropcols, axis = 1)
data_ff = data_ff.drop(['Unnamed: 0','Photo','Flag', 'Club Logo','ID', 'Joined', 'Loaned From', 'Real Face', 'Club', 'Body Type'] , axis = 1)
data_ff = data_ff.dropna()
data_ff.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Potential', 'Value', 'Wage',
#        'Special', 'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Position', 'Jersey Number',
#        'Contract Valid Until', 'Height', 'Weight', 'Crossing', 'Finishing',
#        'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
#        'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', 90)
data_ff.dtypes.head()
# Out:
# Name           object
# Age             int64
# Nationality    object
# Overall         int64
# Potential       int64
# dtype: object

# %%
def obj_to_val(df):
    try:
        val = float(df[1:-1])
        curr = df[-1]
        if curr == 'M':
            val = val * 1000000
        if curr =='K':
            val = val * 1000
    except Exception as ex:
        val = 0
        
    return val

data_ff['Release Clause'] = data_ff['Release Clause'].apply(obj_to_val)
data_ff['Wage'] = data_ff['Wage'].apply(obj_to_val)
data_ff['Value'] = data_ff['Value'].apply(obj_to_val)

def feet_to_cm(df):
    try:
        feet = float(df[0])
        inch = float(df[2:])
        height = feet * 30.84 + inch * 2.54 
    except Exception as ex:
        height = 0.0
    return height

data_ff['Height'] = data_ff['Height'].apply(feet_to_cm)

def weight(df):
    try:
        weight = df[:3]
    except Exception as ex:
        weight = 0
    return weight

data_ff['Weight'] = data_ff['Weight'].apply(weight)

def foot(df):
    if df == 'Left':
        return 1
    else:
        return 0
    
data_ff['Preferred Foot'] = data_ff['Preferred Foot'].apply(foot)

def split_wr0(df):
    split = df.split('/')
    split = [i.strip() for i in split][0]
    return split
def split_wr1(df):
    split = df.split('/')
    split = [i.strip() for i in split][1]
    return split

data_ff['WorkRate1'] = data_ff['Work Rate'].apply(split_wr0)
data_ff['WorkRate2'] = data_ff['Work Rate'].apply(split_wr1)

# %%
data_ff = data_ff.drop(['Work Rate', 'Nationality', 'Jersey Number'],axis = 1)

# %%
## Cleaned Dataset
pd.set_option('display.max_columns', 90)
data_ff.head()
# Out:
#                 Name  Age  Overall  Potential        Value      Wage  Special  \
# 0           L. Messi   31       94         94  110500000.0  565000.0     2202
# 1  Cristiano Ronaldo   33       94         94   77000000.0  405000.0     2228
# 2          Neymar Jr   26       92         93  118500000.0  290000.0     2143
# 3             De Gea   27       91         93   72000000.0  260000.0     1471
# 4       K. De Bruyne   27       91         92  102000000.0  355000.0     2281
#
#    Preferred Foot  International Reputation  Weak Foot  Skill Moves Position  \
# 0               1                       5.0        4.0          4.0       RF
# 1               0                       5.0        4.0          5.0       ST
# 2               0                       5.0        5.0          5.0       LW
# 3               0                       4.0        3.0          1.0       GK
# 4               0                       4.0        5.0          4.0      RCM
#
# ...

# %%
data_ff.shape
# Out:
# (16643, 52)

# %%
data_ff.Age.unique()
# Out:
# array([31, 33, 26, 27, 32, 25, 29, 28, 24, 30, 19, 40, 22, 23, 34, 35, 36,
#        37, 21, 18, 20, 39, 17, 38, 45, 41, 42, 16], dtype=int64)

# %% [markdown]
# #  VISUALIZATION

# %%
corre = data_ff.corr()
plt.figure(figsize = (15,15))
sns.heatmap(corre , cmap = 'Blues')

# %%
plt.figure(figsize = (20,10))
sns.countplot(x = 'Age', data = data_ff)
#sns.distplot(data_ff['Age'], bins = 30)
plt.title('Age VS Count', fontdict={'fontsize':17})
plt.xlabel('Age',fontdict={'fontsize':15})
plt.ylabel("Count", fontdict={'fontsize':15})
plt.tick_params(labelsize = 14)
plt.show()

# %%
#data_ff.hist(figsize = (40,40), edgecolor = 'Black')
#plt.show()

# %%
pr_cols=['Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']

for i in range(len(pr_cols)):
    print('Best {0} : {1}'.format(pr_cols[i], (data_ff['Name'][data_ff[pr_cols[i]] == max(data_ff[pr_cols[i]])].values)[0]))
# Out:
# Best Crossing : K. De Bruyne
# Best Finishing : L. Messi
# Best HeadingAccuracy : Naldo
# Best ShortPassing : L. Modrić
# Best Volleys : E. Cavani
# Best Dribbling : L. Messi
# Best Curve : Quaresma
# Best FKAccuracy : L. Messi
# Best LongPassing : T. Kroos
# Best BallControl : L. Messi
# Best Acceleration : Douglas Costa
# Best SprintSpeed : K. Mbappé
# Best Agility : Neymar Jr
# Best Reactions : Cristiano Ronaldo
# Best Balance : Bernard
# Best ShotPower : Cristiano Ronaldo
# Best Jumping : Cristiano Ronaldo
# Best Stamina : N. Kanté
# Best Strength : A. Akinfenwa
# Best LongShots : L. Messi
# Best Aggression : B. Pearson
# Best Interceptions : N. Kanté
# Best Positioning : Cristiano Ronaldo
# Best Vision : L. Messi
# Best Penalties : M. Balotelli
# Best Composure : L. Messi
# Best Marking : A. Barzagli
# Best StandingTackle : G. Chiellini
# Best SlidingTackle : Sergio Ramos
# Best GKDiving : De Gea
# Best GKHandling : J. Oblak
# Best GKKicking : M. Neuer
# ...

# %%
sns.set(style='darkgrid')
data_mean = data_ff[['Value', 'Release Clause']].mean()
data_tags = ['Value', 'Release Clause']
plt.figure(figsize = (8,6))
plt.xlabel('Type', fontdict={'fontsize':17})
plt.ylabel('Mean Amount', fontdict={'fontsize':17})
plt.title('Type of Value VS Amount', fontdict={'fontsize':20})
plt.tick_params(labelsize = 13)
ax = sns.barplot(x = data_tags, y = data_mean, edgecolor = 'Black')
for i in ax.patches:
    plt.text(i.get_x() + 0.26, i.get_height() + 100000/2, str(round(i.get_height(), 2)), fontdict={'fontsize':12})
plt.show()

# %%
wrk1 = data_ff[['Overall', 'Potential', 'WorkRate1']].groupby('WorkRate1').mean()
wrk2 = data_ff[['Overall', 'Potential', 'WorkRate2']].groupby('WorkRate2').mean()
ax = wrk1.plot(kind = 'bar', figsize = (15,6), edgecolor = 'Black', cmap = 'Paired')
plt.title('WorkRate1(Attack Work Rate) VS Overall-Potential', fontdict = {'fontsize':20})
plt.xlabel('WorkRate1(Attack Work Rate)', fontdict={'fontsize':17})
plt.ylabel('Value', fontdict={'fontsize':17})
plt.tick_params(labelsize = 14)
for i in ax.patches:
    plt.text(i.get_x() + 0.07, i.get_height() + 1 , str(round(i.get_height(), 2)), fontdict={'fontsize':13})

# %%
ax = wrk2.plot(kind = 'bar', figsize = (15,6), edgecolor = 'Black' ,cmap = 'ocean')
plt.title('WorkRate2(Defense Work Rate) VS Overall-Potential', fontdict = {'fontsize':20})
plt.xlabel('WorkRate2(Defense Work Rate)', fontdict={'fontsize':17})
plt.ylabel('Value', fontdict={'fontsize':17})
plt.tick_params(labelsize = 14)
for i in ax.patches:
    plt.text(i.get_x() + 0.07, i.get_height() + 1 , str(round(i.get_height(), 2)), fontdict={'fontsize':13})

# %%
wrk_init = data[['Overall', 'Potential', 'Work Rate']].groupby('Work Rate').mean()
ax = wrk_init.plot(kind = 'bar', figsize = (20,8), edgecolor = 'Black', colormap = 'cividis')
plt.title('Work Rate VS Overall-Potential', fontdict = {'fontsize':20})
plt.xlabel('Work Rate', fontdict={'fontsize':17})
plt.ylabel('Value', fontdict={'fontsize':17})
plt.tick_params(labelsize = 14)
plt.xticks(rotation = 45)
plt.legend(loc = 7)
for i in ax.patches:
    plt.text(i.get_x() + 0.05, i.get_height() + 1 , str(round(i.get_height(), 1)), fontdict={'fontsize':12})

# %%
#Age vs Potential
data_age_pot = data_ff[['Age', 'Potential','Overall']]
data_age_pot = data_age_pot.sort_values(by = 'Age')
data_age_pot = data_age_pot.groupby('Age').mean()
plt.figure(figsize = (15,6))
plt.xticks(range(16,46))
plt.plot(data_age_pot.index, data_age_pot['Potential'], color = 'red', label = 'Potential')
plt.plot( data_age_pot['Overall'], color = 'blue', label = 'Overall')
plt.xlabel('Age',fontdict = {'fontsize':15})
plt.ylabel('Mean Potential and Mean Overall', fontdict={'fontsize':15})
plt.title('Age Vs Potential VS Overall', fontdict = {'fontsize':20})
plt.tick_params(labelsize = 13)
plt.legend()
plt.show()
